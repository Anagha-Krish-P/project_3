# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe ()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.shape
# Out:
# (545, 13)

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
lst=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']  #each unique cateogary is assign to unique integer value
for i in lst:
  df[i]=le.fit_transform(df[i])
  df

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_normalized = df.copy()
df_normalized[df.columns] = scaler.fit_transform(df)

print(df_normalized)
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0    1.000000  0.396564       0.6   0.333333  0.666667       1.0        0.0
# 1    0.909091  0.502405       0.6   1.000000  1.000000       1.0        0.0
# 2    0.909091  0.571134       0.4   0.333333  0.333333       1.0        0.0
# 3    0.906061  0.402062       0.6   0.333333  0.333333       1.0        0.0
# 4    0.836364  0.396564       0.6   0.000000  0.333333       1.0        1.0
# ..        ...       ...       ...        ...       ...       ...        ...
# 540  0.006061  0.092784       0.2   0.000000  0.000000       1.0        0.0
# 541  0.001485  0.051546       0.4   0.000000  0.000000       0.0        0.0
# 542  0.000000  0.135395       0.2   0.000000  0.000000       1.0        0.0
# 543  0.000000  0.086598       0.4   0.000000  0.000000       0.0        0.0
# 544  0.000000  0.151203       0.4   0.000000  0.333333       1.0        0.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_standardized = df.copy()
df_standardized[df.columns] = scaler.fit_transform(df)

print(df_standardized)
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0    4.566365  1.046726  1.403419   1.421812  1.378217  0.405623  -0.465315
# 1    4.004484  1.757010  1.403419   5.405809  2.532024  0.405623  -0.465315
# 2    4.004484  2.218232  0.047278   1.421812  0.224410  0.405623  -0.465315
# 3    3.985755  1.083624  1.403419   1.421812  0.224410  0.405623  -0.465315
# 4    3.554979  1.046726  1.403419  -0.570187  0.224410  0.405623   2.149083
# ..        ...       ...       ...        ...       ...       ...        ...
# 540 -1.576868 -0.991879 -1.308863  -0.570187 -0.929397  0.405623  -0.465315
# 541 -1.605149 -1.268613  0.047278  -0.570187 -0.929397 -2.465344  -0.465315
# 542 -1.614327 -0.705921 -1.308863  -0.570187 -0.929397  0.405623  -0.465315
# 543 -1.614327 -1.033389  0.047278  -0.570187 -0.929397 -2.465344  -0.465315
# 544 -1.614327 -0.599839  0.047278  -0.570187  0.224410  0.405623  -0.465315
#
# ...

# %%
df = pd.get_dummies(df, columns=['furnishingstatus'], drop_first=True)

# %%
df.corr()
# Out:
#                        price      area  bedrooms  bathrooms   stories  \
# price               1.000000  0.535997  0.366494   0.517545  0.420712
# area                0.535997  1.000000  0.151858   0.193820  0.083996
# bedrooms            0.366494  0.151858  1.000000   0.373930  0.408564
# bathrooms           0.517545  0.193820  0.373930   1.000000  0.326165
# stories             0.420712  0.083996  0.408564   0.326165  1.000000
# mainroad            0.296898  0.288874 -0.012033   0.042398  0.121706
# guestroom           0.255517  0.140297  0.080549   0.126469  0.043538
# basement            0.187057  0.047417  0.097312   0.102106 -0.172394
# hotwaterheating     0.093073 -0.009229  0.046049   0.067159  0.018847
# airconditioning     0.452954  0.222393  0.160603   0.186915  0.293602
# parking             0.384394  0.352980  0.139270   0.177496  0.045547
# prefarea            0.329777  0.234779  0.079023   0.063472  0.044425
# ...

# %%
fig,ax = plt.subplots(figsize=(7,6))
sns.heatmap(df.corr(),annot=True,linewidths=0.3,ax=ax)
# Out:
# <Axes: >

# %%
num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']
plt.figure(figsize=(18, 12))

for i, col in enumerate(num_cols):
    plt.subplot(3, 3, i + 1)
    plt.hist(df[col].dropna(), bins=20, color='teal', edgecolor='blue')
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

# First subplot - Age
plt.subplot(1, 2, 1)
sns.boxplot(y=df['price'], color='#a93226')
plt.title('Boxplot of price')

# Second subplot - Fare
plt.subplot(1, 2, 2)
sns.boxplot(y=df['area'], color='#b03a2e')
plt.title('Boxplot of area')

plt.tight_layout()
plt.show()

# %%
cols = ['area', 'price']

for col in cols:
    # Calculate IQR
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    # Replace outliers with the mean of the column
    mean_val = df[col].mean()
    df[col] = df[col].apply(lambda x: mean_val if x < lower or x > upper else x)

    # Plot boxplot
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col.capitalize()}')
    plt.show()

# %%
df.dtypes
# Out:
# price               float64
# area                float64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# mainroad              int64
# guestroom             int64
# basement              int64
# hotwaterheating       int64
# airconditioning       int64
# parking               int64
# prefarea              int64
# furnishingstatus      int64
# dtype: object

# %%
x=df.drop(columns='price')
x
# Out:
#             area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420.000000         4          2        3         1          0         0
# 1    8960.000000         4          4        4         1          0         0
# 2    4924.678848         3          2        2         1          0         1
# 3    7500.000000         4          2        2         1          0         1
# 4    7420.000000         4          1        2         1          1         1
# ..           ...       ...        ...      ...       ...        ...       ...
# 540  3000.000000         2          1        1         1          0         1
# 541  2400.000000         3          1        1         0          0         0
# 542  3620.000000         2          1        1         1          0         0
# 543  2910.000000         3          1        1         0          0         0
# 544  3850.000000         3          1        2         1          0         0
#
# ...

# %%
y = df.iloc[:, 0]
y
# Out:
# 0      4.766729e+06
# 1      4.766729e+06
# 2      4.766729e+06
# 3      4.766729e+06
# 4      4.766729e+06
#            ...
# 540    1.820000e+06
# 541    1.767150e+06
# 542    1.750000e+06
# 543    1.750000e+06
# 544    1.750000e+06
# Name: price, Length: 545, dtype: float64

# %%
df['price'].value_counts()
# Out:
# price
# 3.500000e+06    17
# 4.200000e+06    17
# 4.766729e+06    15
# 4.900000e+06    12
# 5.250000e+06     9
#                 ..
# 2.135000e+06     1
# 1.960000e+06     1
# 1.855000e+06     1
# 1.820000e+06     1
# 1.767150e+06     1
# Name: count, Length: 208, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)# 80% training, 20% testing

x_train
# Out:
#        area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 46   6000.0         3          2        4         1          0         0
# 93   7200.0         3          2        1         1          0         1
# 335  3816.0         2          1        1         1          0         1
# 412  2610.0         3          1        2         1          0         1
# 471  3750.0         3          1        2         1          0         0
# ..      ...       ...        ...      ...       ...        ...       ...
# 71   6000.0         4          2        4         1          0         0
# 106  5450.0         4          2        1         1          0         1
# 270  4500.0         3          2        3         1          0         0
# 435  4040.0         2          1        1         1          0         0
# 102  5500.0         3          2        4         1          1         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
print("Training set size:", x_train.shape)
print("Test set size:", x_test.shape)
# Out:
# Training set size: (436, 12)
# Test set size: (109, 12)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("Intercept:", model.intercept_)

print("Coefficients:")
for feature, coef in zip(x.columns, model.coef_):
    print(f"{feature}: {coef:.2f}")
# Out:
# Intercept: 1015262.5687934384
# Coefficients:
# area: 258.56
# bedrooms: 59448.05
# bathrooms: 558469.88
# stories: 429381.72
# mainroad: 386854.00
# guestroom: 220891.39
# basement: 359182.81
# hotwaterheating: 465913.00
# airconditioning: 518620.33
# parking: 96202.95
# prefarea: 489305.22
# furnishingstatus: -230219.17

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 878896.66
# Mean Squared Error (MSE): 1262253722977.39
# R² Score: 0.5183

# %%
plt.figure(figsize=(8, 5))
plt.scatter(x_test['area'], y_test, color='skyblue', label='Actual Price')
plt.plot(x_test['area'], model.predict(x_test), color='teal', label='Predicted Price Line')

plt.xlabel('Area (in sq ft)')
plt.ylabel('Price')
plt.title('Linear Regression: Area vs Price')
plt.legend()
plt.grid(True)
plt.show()
