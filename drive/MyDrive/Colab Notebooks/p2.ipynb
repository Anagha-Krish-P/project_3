# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns = df.columns.str.strip()  # Removes tabs, spaces, etc.

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# Fill missing values with the mode (most frequent value)
df['Cabin'] = df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
lst=['Name','Sex','Ticket','Cabin','Embarked']  #each unique cateogary is assign to unique integer value
for i in lst:
  df[i]=le.fit_transform(df[i])
  df

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_normalized = df.copy()
df_normalized[df.columns] = scaler.fit_transform(df)

print(df_normalized)
# Out:
#      PassengerId  Survived  Pclass      Name  Sex       Age  SibSp     Parch  \
# 0       0.000000       0.0     1.0  0.121348  1.0  0.271174  0.125  0.000000
# 1       0.001124       1.0     0.0  0.213483  0.0  0.472229  0.125  0.000000
# 2       0.002247       1.0     1.0  0.396629  0.0  0.321438  0.000  0.000000
# 3       0.003371       1.0     0.0  0.305618  0.0  0.434531  0.125  0.000000
# 4       0.004494       0.0     1.0  0.016854  1.0  0.434531  0.000  0.000000
# ..           ...       ...     ...       ...  ...       ...    ...       ...
# 886     0.995506       0.0     0.5  0.615730  1.0  0.334004  0.000  0.000000
# 887     0.996629       1.0     0.0  0.340449  0.0  0.233476  0.000  0.000000
# 888     0.997753       0.0     1.0  0.464045  0.0  0.367921  0.125  0.333333
# 889     0.998876       1.0     0.0  0.091011  1.0  0.321438  0.000  0.000000
# 890     1.000000       0.0     1.0  0.247191  1.0  0.396833  0.000  0.000000
#
#        Ticket      Fare     Cabin  Embarked
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_standardized = df.copy()
df_standardized[df.columns] = scaler.fit_transform(df)

print(df_standardized)
# Out:
#      PassengerId  Survived    Pclass      Name       Sex       Age     SibSp  \
# 0      -1.730108 -0.789272  0.827377 -1.310217  0.737695 -0.592481  0.432793
# 1      -1.726220  1.266990 -1.566107 -0.991410 -1.355574  0.638789  0.432793
# 2      -1.722332  1.266990  0.827377 -0.357685 -1.355574 -0.284663 -0.474545
# 3      -1.718444  1.266990 -1.566107 -0.672604 -1.355574  0.407926  0.432793
# 4      -1.714556 -0.789272  0.827377 -1.671790  0.737695  0.407926 -0.474545
# ..           ...       ...       ...       ...       ...       ...       ...
# 886     1.714556 -0.789272 -0.369365  0.400452  0.737695 -0.207709 -0.474545
# 887     1.718444  1.266990 -1.566107 -0.552079 -1.355574 -0.823344 -0.474545
# 888     1.722332 -0.789272  0.827377 -0.124412 -1.355574  0.000000  0.432793
# 889     1.726220  1.266990 -1.566107 -1.415189  0.737695 -0.284663 -0.474545
# 890     1.730108 -0.789272  0.827377 -0.874774  0.737695  0.177063 -0.474545
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    1  22.000000      1      0
# 1              2         1       1   190    0  38.000000      1      0
# 2              3         1       3   353    0  26.000000      0      0
# 3              4         1       1   272    0  35.000000      1      0
# 4              5         0       3    15    1  35.000000      0      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886          887         0       2   548    1  27.000000      0      0
# 887          888         1       1   303    0  19.000000      0      0
# 888          889         0       3   413    0  29.699118      1      2
# 889          890         1       1    81    1  26.000000      0      0
# 890          891         0       3   220    1  32.000000      0      0
#
#      Ticket     Fare  Cabin  Embarked
# 0       523   7.2500     47         2
# ...

# %% [markdown]
# # ***visualizing numerical variable ***

# %%
num_cols = ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
plt.figure(figsize=(18, 12))  # Adjust size as needed

# Loop through each numerical column and plot histogram
for i, col in enumerate(num_cols):
    plt.subplot(3, 3, i + 1)  # 3 rows, 3 columns of plots
    plt.hist(df[col].dropna(), bins=20, color='#598dba', edgecolor='black')
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# # *continuous variable visual representation *

# %%
plt.figure(figsize=(12, 6))

# First subplot - Age
plt.subplot(1, 2, 1)
sns.boxplot(y=df['Age'], color='#a93226')
plt.title('Boxplot of Age')

# Second subplot - Fare
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Fare'], color='#b03a2e')
plt.title('Boxplot of Fare')

plt.tight_layout()
plt.show()

# %%
q1=df['Age'].quantile(0.25)
q3=df['Age'].quantile(0.75)
iqr=q3-q1
lower=q1-(iqr*1.5)
upper=q3+(iqr*1.5)
for i in df['Age']:
  if i<lower or i>upper:
    df['Age']=df['Age'].replace(i,np.mean(df['Age']))
# This line was previously incorrectly indented inside the for loop
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
q1=df['Fare'].quantile(0.25)
q3=df['Fare'].quantile(0.75)
iqr=q3-q1
lower=q1-(iqr*1.5)
upper=q3+(iqr*1.5)
for i in df['Fare']:
  if i<lower or i>upper:
    df['Fare']=df['Fare'].replace(i,np.mean(df['Fare']))
# This line was previously incorrectly indented inside the for loop
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939 -0.009811
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.001883
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900  0.004692
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.119076
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.024819
# Age            -0.009811 -0.001883  0.004692  0.119076  0.024819  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631  0.033822
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.026100
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.006348
# Fare           -0.014734  0.211344 -0.589459 -0.066110 -0.168242  0.048020
# Cabin          -0.018086  0.175690 -0.248495  0.034129 -0.102643 -0.018656
# ...

# %%
fig,ax = plt.subplots(figsize=(10,9))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,ax=ax)
# Out:
# <Axes: >

# %%
features = ['Age', 'Fare', 'Pclass', 'SibSp', 'Parch', 'Survived']

# Pairplot with class hue
sns.pairplot(df[features], hue='Survived', diag_kind='kde', corner=True)
plt.suptitle('Pairplot of Selected Features by Survival', y=1.02)
plt.show()
